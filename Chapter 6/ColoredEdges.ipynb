# %%
def ChromosomeToCycle(Chromosome):
    Nodes = [0]*(2*len(Chromosome))
    for j in range(len(Chromosome)):
        i = Chromosome[j]
        if i > 0:
            Nodes[2*j] = 2*i-1
            Nodes[2*j+1] = 2*i
        else:
            Nodes[2*j] = -2*i
            Nodes[2*j+1] = -2*i-1
    return Nodes

def ColoredEdges(P):
    Edges = list()
    for chromosome in P:
        Nodes = ChromosomeToCycle(chromosome)
        n = len(Nodes)
        for j in range(1,n,2):
            if j != n-1:
                Edges.append([Nodes[j], Nodes[j+1]])
            else:
                Edges.append([Nodes[j], Nodes[0]])
    return Edges

# %%
with open("dataset_865712_7.txt") as f: 
    P = f.readline().strip()
    P = P[1:-1]
    P = P.split(')(')
    for i in range(len(P)):
        P[i] = [int(x) for x in P[i].split(' ')]
    ans = ColoredEdges(P)

# %%
for element in ans:
    print("(" + str(element[0]) + ",", ''.join(map(str, element[1:])), end = "), ")
# Out:
# (1, 4), (3, 6), (5, 7), (8, 9), (10, 11), (12, 13), (14, 16), (15, 17), (18, 20), (19, 21), (22, 23), (24, 25), (26, 27), (28, 30), (29, 31), (32, 34), (33, 36), (35, 37), (38, 40), (39, 42), (41, 43), (44, 46), (45, 48), (47, 50), (49, 52), (51, 54), (53, 55), (56, 58), (57, 60), (59, 61), (62, 2), (64, 65), (66, 67), (68, 69), (70, 72), (71, 73), (74, 75), (76, 77), (78, 79), (80, 81), (82, 83), (84, 86), (85, 88), (87, 90), (89, 92), (91, 94), (93, 96), (95, 98), (97, 100), (99, 102), (101, 103), (104, 105), (106, 107), (108, 109), (110, 111), (112, 63), (114, 115), (116, 117), (118, 119), (120, 122), (121, 124), (123, 126), (125, 128), (127, 129), (130, 131), (132, 133), (134, 135), (136, 137), (138, 140), (139, 142), (141, 143), (144, 145), (146, 148), (147, 149), (150, 151), (152, 154), (153, 113), (156, 157), (158, 160), (159, 161), (162, 163), (164, 166), (165, 168), (167, 170), (169, 171), (172, 174), (173, 176), (175, 178), (177, 179), (180, 181), (182, 183), (184, 185), (186, 188), (187, 190), (189, 192), (191, 194), (193, 195), (196, 198), (197, 200), (199, 201), (202, 204), (203, 206), (205, 207), (208, 155), (210, 212), (211, 214), (213, 215), (216, 217), (218, 219), (220, 222), (221, 224), (223, 225), (226, 228), (227, 230), (229, 232), (231, 233), (234, 236), (235, 237), (238, 239), (240, 241), (242, 244), (243, 245), (246, 247), (248, 250), (249, 252), (251, 254), (253, 256), (255, 258), (257, 260), (259, 262), (261, 209), (264, 265), (266, 267), (268, 269), (270, 271), (272, 273), (274, 276), (275, 278), (277, 280), (279, 282), (281, 283), (284, 285), (286, 288), (287, 289), (290, 291), (292, 293), (294, 296), (295, 297), (298, 300), (299, 301), (302, 304), (303, 306), (305, 308), (307, 310), (309, 263), (312, 314), (313, 316), (315, 318), (317, 319), (320, 321), (322, 324), (323, 326), (325, 327), (328, 329), (330, 331), (332, 334), (333, 336), (335, 338), (337, 339), (340, 342), (341, 343), (344, 345), (346, 348), (347, 350), (349, 351), (352, 353), (354, 356), (355, 358), (357, 311), (360, 361), (362, 363), (364, 365), (366, 367), (368, 369), (370, 371), (372, 373), (374, 375), (376, 377), (378, 379), (380, 382), (381, 384), (383, 386), (385, 387), (388, 390), (389, 392), (391, 394), (393, 396), (395, 397), (398, 400), (399, 402), (401, 403), (404, 359),
