# %%
#Compute the Hamming Distance Between Two Strings
def HammingDistance(x, y):
    dist = 0
    for i in range(len(x)):
        if x[i] != y[i]:
            dist += 1
    return dist

# %%
x = "..."
y = "..."
HammingDistance(x,y)
# Out:
# 882
